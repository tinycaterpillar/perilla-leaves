# %%
import math
import matplotlib.pyplot as plt
from dataclasses import dataclass
from datetime import datetime
import time

import diffrax
import equinox as eqx
import jax
import jax.lax as lax
import jax.numpy as jnp
import jax.nn as jnn
import jax.random as jr
import numpy as np
import optax  # https://github.com/deepmind/optax

# %%
# MLP
class Func(eqx.Module):
    mlp: eqx.nn.MLP

    def __init__(self, in_size, out_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        self.mlp = eqx.nn.MLP(
            in_size=in_size,
            out_size=out_size,
            width_size=width_size,
            depth=depth,
            # activation=jnn.tanh, 결과가 더 안 좋음
            activation=jnn.softplus,
            key=key,
        )

    def __call__(self, t):
        if jnp.shape(t) == ():
            t = jnp.broadcast_to(t, (1,))
        return self.mlp(t)

# %%
@dataclass
class SIRConfig:
    beta: float = 0.025
    alpha: float = 0.2
    S0: float = 100.0
    I0: float = 1.0
    t0: float = 0.0
    t1: float = 30.0

    def y0(self):
        return jnp.array([self.S0, self.I0])

    def args(self):
        return (self.beta, self.alpha)

# %%
def get_data(dataset_size, config, ts=None, *, key):
    # Initial condition: (S0, I0)
    # y0 = jr.uniform(key, (2,), minval=0, maxval=100)
    y0 = config.y0()
    ts = jnp.linspace(config.t0, config.t1, dataset_size) if ts is None else ts

    def f(t, y, args):
        beta, alpha = args
        S, I = y
        dSdt = -beta * S * I
        dIdt = beta * S * I - alpha * I
        return jnp.array([dSdt, dIdt])

    solver = diffrax.Tsit5()
    dt0 = 0.1
    saveat = diffrax.SaveAt(ts=ts)
    sol = diffrax.diffeqsolve(
        (diffrax.ODETerm(f)), solver, 0, ts[-1], dt0, y0, args=config.args(), saveat=saveat
    )
    ys = sol.ys
    return ts, ys

# %%
def dataloader(arrays, batch_size, *, key):
    dataset_size = arrays[0].shape[0]
    assert all(array.shape[0] == dataset_size for array in arrays)
    indices = np.arange(dataset_size)
    while True:
        perm = jr.permutation(key, indices)
        (key,) = jr.split(key, 1)
        start = 0
        end = batch_size
        while end <= dataset_size:
            batch_perm = perm[start:end]
            yield tuple(array[batch_perm] for array in arrays)
            start = end
            end = start + batch_size

# %%
def relative_error(pred, true):
    assert(pred.shape == true.shape)
    
    if pred.ndim == 0:  # Scalar case
        return jnp.abs(pred - true) / jnp.abs(true)
    else:  # Vector (or higher-dimension) case
        return jnp.linalg.norm(pred - true, 2) / jnp.linalg.norm(true, 2)
    
def get_experiment_id():
    return datetime.now().strftime("%Y%m%d%H%M%S%f")

# %%
def main(
    dataset_size=10,
    collocation_size=500,
    batch_size=10, # batch_size == dataset_size
    lr=3e-3,
    steps=20000,
    width_size=64,
    depth=2,
    seed=5678,
    config=SIRConfig(),
    plot=True
):
    test_data_key, data_key, col_key, model_key, loader_key = jr.split(jr.PRNGKey(seed), 5)
    ts, ys = get_data(dataset_size, config=config, key=data_key)
    cs = jr.uniform(col_key, (collocation_size,), minval=config.t0 + 0.001, maxval=config.t1 - 0.001)

    model = Func(in_size=1, out_size=2, width_size=width_size, depth=depth, key=model_key)
    optim = optax.adam(lr)
    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    @eqx.filter_jit
    def pde_residual(network, x):
        beta, alpha = config.args()
        pred = network(x)
        S, I = pred[0], pred[1]
        jac = jax.jacrev(network)(x)
        dSdt, dIdt = jac[0], jac[1]

        res_S = dSdt + beta * S * I
        res_I = dIdt - beta * S * I + alpha * I

        ret = jnp.square(res_S) + jnp.square(res_I)
        return ret
    
    @eqx.filter_value_and_grad
    def grad_loss(model, ti, yi):
        residual_at_col = jax.vmap(pde_residual, in_axes=(None, 0))(model, cs)
        col_loss = jnp.mean(residual_at_col)
        
        y_pred = jax.vmap(model)(ti)
        data_loss = jnp.mean((y_pred - yi)**2)
        
        y0_pred = model(config.t0)
        init_loss = jnp.mean((y0_pred - config.y0())**2)

        total_loss = col_loss + data_loss + init_loss
        return total_loss

    @eqx.filter_jit
    def make_step(model, ti, yi, opt_state):
        loss, grads = grad_loss(model, ti, yi)
        updates, opt_state = optim.update(grads, opt_state)
        model = eqx.apply_updates(model, updates)
        return loss, model, opt_state

    loss_list = []
    for step, (ti, yi) in zip(range(steps), dataloader((ts, ys), batch_size, key=loader_key)):
        start = time.time()
        loss, model, opt_state = make_step(model, ti, yi, opt_state)
        loss = loss.item()
        loss_list.append(loss)
        end = time.time()
        if step % 100 == 0:
            print(f"step={step}, loss={loss}, Computation time: {end - start}")

    if plot:
        exact_ts, exact_ys = get_data(1000, config=config, key=test_data_key)
        model_y = jax.vmap(model)(exact_ts)

        # relative error 계산
        rel_S = relative_error(exact_ys[:, 0], model_y[:, 0])
        rel_I = relative_error(exact_ys[:, 1], model_y[:, 1])

        # Figure setup
        figure = plt.figure(figsize=(15,5))
        plt.suptitle(f'Results - PINN')

        # Subplot for Susceptible (S)
        ax1 = figure.add_subplot(1,3,1)
        ax1.plot(exact_ts, exact_ys[:, 0], color='C0', label="Susceptible")
        ax1.plot(exact_ts, model_y[:, 0], linestyle='--', lw=2, color='C2', label='Trained NN')
        ax1.scatter(ts, ys[:, 0], color='red', marker='x', label='Sampled Susceptible', alpha=0.6)
        ax1.set_title(f'S(Relative error: {rel_S:.2e})')
        ax1.set_xlabel('t')
        ax1.legend()

        # Subplot for Infected (I)
        ax2 = figure.add_subplot(1,3,2)
        ax2.plot(exact_ts, exact_ys[:, 1], color='C1', label="Infected")
        ax2.plot(exact_ts, model_y[:, 1], linestyle='--', lw=2, color='C3', label='Trained NN')
        ax2.scatter(ts, ys[:, 1], color='red', marker='x', label='Sampled Infected', alpha=0.6)
        ax2.set_title(f'I(Relative error: {rel_I:.2e})')
        ax2.set_xlabel('t')
        ax2.legend()

        # Subplot for Training Loss
        ax3 = figure.add_subplot(1,3,3)
        ax3.plot(loss_list, label='loss_total')
        ax3.set_yscale('log')  # y축을 로그 스케일로 변경
        ax3.set_ylim(1e-6, 1e1)  # 적당한 범위로 설정 (필요하면 조정 가능)
        ax3.set_title('loss')
        ax3.set_xlabel('epoch')
        ax3.legend()

        plt.tight_layout()
        plt.savefig(f"result/pinn_{get_experiment_id()}.png")

    return ts, ys, model

# %%
ts, ys, model = main()
# Out:
# step=0, loss=5850.5498046875, Computation time: 0.7180318832397461
# step=100, loss=325.83929443359375, Computation time: 0.0
# step=200, loss=48.42570877075195, Computation time: 0.0
# step=300, loss=25.60958480834961, Computation time: 0.0
# step=400, loss=20.242233276367188, Computation time: 0.0018968582153320312
# step=500, loss=15.7335844039917, Computation time: 0.0020029544830322266
# step=600, loss=13.460310935974121, Computation time: 0.0
# step=700, loss=11.408401489257812, Computation time: 0.002539396286010742
# step=800, loss=10.331302642822266, Computation time: 0.0020074844360351562
# step=900, loss=8.290582656860352, Computation time: 0.0025501251220703125
# step=1000, loss=7.010124683380127, Computation time: 0.0
# step=1100, loss=5.851047039031982, Computation time: 0.0025548934936523438
# step=1200, loss=4.792743682861328, Computation time: 0.0
# step=1300, loss=3.827634811401367, Computation time: 0.0024268627166748047
# step=1400, loss=3.089845657348633, Computation time: 0.0
# step=1500, loss=2.2159907817840576, Computation time: 0.0
# step=1600, loss=1.6965829133987427, Computation time: 0.0
# step=1700, loss=1.1626378297805786, Computation time: 0.0
# step=1800, loss=3.499727964401245, Computation time: 0.0
# step=1900, loss=0.6544443368911743, Computation time: 0.0011167526245117188
# step=2000, loss=0.5243273973464966, Computation time: 0.015957117080688477
# step=2100, loss=0.4583786725997925, Computation time: 0.0020072460174560547
# step=2200, loss=0.3901757597923279, Computation time: 0.0
# step=2300, loss=7.069501876831055, Computation time: 0.0
# step=2400, loss=0.32427769899368286, Computation time: 0.0
# step=2500, loss=0.2983373701572418, Computation time: 0.0
# step=2600, loss=0.27593421936035156, Computation time: 0.0010001659393310547
# step=2700, loss=0.25707006454467773, Computation time: 0.003916263580322266
# step=2800, loss=0.23675823211669922, Computation time: 0.0019838809967041016
# step=2900, loss=0.22429703176021576, Computation time: 0.0020046234130859375
# step=3000, loss=0.20496879518032074, Computation time: 0.0
# step=3100, loss=0.19124889373779297, Computation time: 0.0
# step=3200, loss=0.1813933402299881, Computation time: 0.0
# step=3300, loss=0.1705542355775833, Computation time: 0.016592741012573242
# step=3400, loss=4.113098621368408, Computation time: 0.002867460250854492
# step=3500, loss=0.1539483219385147, Computation time: 0.0029952526092529297
# step=3600, loss=0.1456279307603836, Computation time: 0.0
# step=3700, loss=2.6855075359344482, Computation time: 0.0
# step=3800, loss=0.1330537497997284, Computation time: 0.0
# step=3900, loss=0.12612538039684296, Computation time: 0.0
# step=4000, loss=0.11978605389595032, Computation time: 0.0
# step=4100, loss=0.11461148411035538, Computation time: 0.0
# step=4200, loss=0.10819659382104874, Computation time: 0.0
# step=4300, loss=0.12608563899993896, Computation time: 0.0009925365447998047
# step=4400, loss=0.09804671257734299, Computation time: 0.0009479522705078125
# step=4500, loss=0.5821018815040588, Computation time: 0.0
# step=4600, loss=0.08910222351551056, Computation time: 0.0007212162017822266
# step=4700, loss=0.08431535214185715, Computation time: 0.0018961429595947266
# step=4800, loss=0.08738085627555847, Computation time: 0.0006818771362304688
# step=4900, loss=0.07695242762565613, Computation time: 0.0
# step=5000, loss=0.0730481818318367, Computation time: 0.017308473587036133
# step=5100, loss=0.0757758840918541, Computation time: 0.0
# step=5200, loss=0.06692860275506973, Computation time: 0.01573967933654785
# step=5300, loss=1.047760248184204, Computation time: 0.0
# step=5400, loss=0.06144886463880539, Computation time: 0.0
# step=5500, loss=0.05841583013534546, Computation time: 0.0
# step=5600, loss=0.05950954183936119, Computation time: 0.0
# step=5700, loss=0.05407331511378288, Computation time: 0.0036101341247558594
# step=5800, loss=0.053529541939496994, Computation time: 0.00655674934387207
# step=5900, loss=0.05117635056376457, Computation time: 0.0
# step=6000, loss=0.04832630231976509, Computation time: 0.0020117759704589844
# step=6100, loss=0.3908393085002899, Computation time: 0.007121086120605469
# step=6200, loss=0.045299213379621506, Computation time: 0.006690502166748047
# step=6300, loss=0.043479498475790024, Computation time: 0.0
# step=6400, loss=0.05199354887008667, Computation time: 0.0
# step=6500, loss=0.04041780158877373, Computation time: 0.0
# step=6600, loss=0.10455510020256042, Computation time: 0.0
# step=6700, loss=0.03823229670524597, Computation time: 0.010762214660644531
# step=6800, loss=0.03677603602409363, Computation time: 0.0
# step=6900, loss=0.12968142330646515, Computation time: 0.001004934310913086
# step=7000, loss=0.03509911149740219, Computation time: 0.0
# step=7100, loss=0.03401745855808258, Computation time: 0.0
# step=7200, loss=0.045886341482400894, Computation time: 0.0
# step=7300, loss=0.03259310871362686, Computation time: 0.0
# step=7400, loss=0.09084731340408325, Computation time: 0.0
# step=7500, loss=0.03169756010174751, Computation time: 0.015979290008544922
# step=7600, loss=0.03041582740843296, Computation time: 0.0
# step=7700, loss=0.15777762234210968, Computation time: 0.002302885055541992
# step=7800, loss=0.029249899089336395, Computation time: 0.004706621170043945
# step=7900, loss=0.030403753742575645, Computation time: 0.002012491226196289
# step=8000, loss=0.028593124821782112, Computation time: 0.012024402618408203
# step=8100, loss=0.02753741480410099, Computation time: 0.0019974708557128906
# step=8200, loss=0.5413400530815125, Computation time: 0.005768299102783203
# step=8300, loss=0.02686152793467045, Computation time: 0.0015048980712890625
# step=8400, loss=0.026208098977804184, Computation time: 0.0019757747650146484
# step=8500, loss=0.047771867364645004, Computation time: 0.002058744430541992
# step=8600, loss=0.025672195479273796, Computation time: 0.009722471237182617
# step=8700, loss=0.025098254904150963, Computation time: 0.0022728443145751953
# step=8800, loss=0.14850659668445587, Computation time: 0.0
# step=8900, loss=0.02462146431207657, Computation time: 0.0014030933380126953
# step=9000, loss=0.02411908097565174, Computation time: 0.014865636825561523
# step=9100, loss=0.05302048474550247, Computation time: 0.010507583618164062
# step=9200, loss=0.023651251569390297, Computation time: 0.016619443893432617
# step=9300, loss=0.023451484739780426, Computation time: 0.0
# step=9400, loss=0.02393534779548645, Computation time: 0.0019381046295166016
# step=9500, loss=0.0227982010692358, Computation time: 0.0
# step=9600, loss=0.06498738378286362, Computation time: 0.0
# step=9700, loss=0.02253047004342079, Computation time: 0.0
# step=9800, loss=0.022045793011784554, Computation time: 0.0020017623901367188
# step=9900, loss=0.19914370775222778, Computation time: 0.0
# step=10000, loss=0.02166709676384926, Computation time: 0.011264324188232422
# step=10100, loss=0.025809982791543007, Computation time: 0.0
# step=10200, loss=0.021928593516349792, Computation time: 0.0
# step=10300, loss=0.0209732074290514, Computation time: 0.0
# step=10400, loss=0.04828982800245285, Computation time: 0.0
# step=10500, loss=0.020646121352910995, Computation time: 0.0019931793212890625
# step=10600, loss=0.08439084887504578, Computation time: 0.0
# step=10700, loss=0.020619327202439308, Computation time: 0.0019252300262451172
# step=10800, loss=0.020004799589514732, Computation time: 0.001981019973754883
# step=10900, loss=0.06135522201657295, Computation time: 0.0029993057250976562
# step=11000, loss=0.019758380949497223, Computation time: 0.001916646957397461
# step=11100, loss=0.01966000720858574, Computation time: 0.0
# step=11200, loss=0.020128801465034485, Computation time: 0.0019114017486572266
# step=11300, loss=0.019275495782494545, Computation time: 0.002414703369140625
# step=11400, loss=0.029959511011838913, Computation time: 0.0
# step=11500, loss=0.019473502412438393, Computation time: 0.0
# step=11600, loss=0.01876206137239933, Computation time: 0.001911163330078125
# step=11700, loss=0.12467613816261292, Computation time: 0.0
# step=11800, loss=0.01868223398923874, Computation time: 0.0
# step=11900, loss=0.01834658347070217, Computation time: 0.0
# step=12000, loss=0.2241826206445694, Computation time: 0.0
# step=12100, loss=0.01815742254257202, Computation time: 0.0
# step=12200, loss=0.019207192584872246, Computation time: 0.0
# step=12300, loss=0.018116002902388573, Computation time: 0.0
# step=12400, loss=0.017658531665802002, Computation time: 0.015277624130249023
# step=12500, loss=0.3649882376194, Computation time: 0.0029821395874023438
# step=12600, loss=0.01772109419107437, Computation time: 0.0
# step=12700, loss=0.01739852875471115, Computation time: 0.0
# step=12800, loss=0.017152387648820877, Computation time: 0.0
# step=12900, loss=0.01824977435171604, Computation time: 0.0
# step=13000, loss=0.016977030783891678, Computation time: 0.0
# step=13100, loss=0.21010853350162506, Computation time: 0.0020368099212646484
# step=13200, loss=0.016831137239933014, Computation time: 0.0
# step=13300, loss=0.016781670972704887, Computation time: 0.015877723693847656
# step=13400, loss=0.01732814684510231, Computation time: 0.00041961669921875
# step=13500, loss=0.016385037451982498, Computation time: 0.0
# step=13600, loss=0.08271327614784241, Computation time: 0.0
# step=13700, loss=0.01624273881316185, Computation time: 0.0019750595092773438
# step=13800, loss=0.018397871404886246, Computation time: 0.003648519515991211
# step=13900, loss=0.01632811687886715, Computation time: 0.0016093254089355469
# step=14000, loss=0.015849968418478966, Computation time: 0.0015685558319091797
# step=14100, loss=0.04049103334546089, Computation time: 0.0
# step=14200, loss=0.015790443867444992, Computation time: 0.0005834102630615234
# step=14300, loss=0.015509696677327156, Computation time: 0.0
# step=14400, loss=0.027500519528985023, Computation time: 0.016577720642089844
# step=14500, loss=0.015414230525493622, Computation time: 0.0
# step=14600, loss=0.015308914706110954, Computation time: 0.0
# step=14700, loss=0.015938609838485718, Computation time: 0.0
# step=14800, loss=0.015079325065016747, Computation time: 0.0
# step=14900, loss=1.198883295059204, Computation time: 0.0
# step=15000, loss=0.015025576576590538, Computation time: 0.003922939300537109
# step=15100, loss=0.014729871414601803, Computation time: 0.0
# step=15200, loss=0.025475913658738136, Computation time: 0.0019788742065429688
# step=15300, loss=0.014639356173574924, Computation time: 0.0
# step=15400, loss=0.04645612835884094, Computation time: 0.003233194351196289
# step=15500, loss=0.014765099622309208, Computation time: 0.0
# step=15600, loss=0.014354648999869823, Computation time: 0.002980947494506836
# step=15700, loss=0.7838243842124939, Computation time: 0.0
# step=15800, loss=0.014604289084672928, Computation time: 0.0
# step=15900, loss=0.0141429603099823, Computation time: 0.0
# step=16000, loss=0.01967514120042324, Computation time: 0.0
# step=16100, loss=0.014276271685957909, Computation time: 0.0
# step=16200, loss=0.013788757845759392, Computation time: 0.0
# step=16300, loss=0.017685100436210632, Computation time: 0.0
# step=16400, loss=0.013690288178622723, Computation time: 0.014890909194946289
# step=16500, loss=0.1648135930299759, Computation time: 0.0
# step=16600, loss=0.013594506308436394, Computation time: 0.016835927963256836
# step=16700, loss=0.013829057104885578, Computation time: 0.0
# step=16800, loss=0.013739463873207569, Computation time: 0.016779422760009766
# step=16900, loss=0.013277527876198292, Computation time: 0.0
# step=17000, loss=0.021758949384093285, Computation time: 0.0
# step=17100, loss=0.013202421367168427, Computation time: 0.0
# step=17200, loss=0.013383174315094948, Computation time: 0.0
# step=17300, loss=0.013486495241522789, Computation time: 0.0
# step=17400, loss=0.012924842536449432, Computation time: 0.0
# step=17500, loss=0.10066845268011093, Computation time: 0.0
# step=17600, loss=0.012892083264887333, Computation time: 0.0
# step=17700, loss=0.012652677483856678, Computation time: 0.0
# step=17800, loss=0.016421642154455185, Computation time: 0.0
# step=17900, loss=0.01259821467101574, Computation time: 0.0
# step=18000, loss=0.027945950627326965, Computation time: 0.0
# step=18100, loss=0.012762798927724361, Computation time: 0.0019338130950927734
# step=18200, loss=0.01236327737569809, Computation time: 0.0016655921936035156
# step=18300, loss=0.4153251051902771, Computation time: 0.0029108524322509766
# step=18400, loss=0.012379133142530918, Computation time: 0.0
# step=18500, loss=0.012129856273531914, Computation time: 0.0
# step=18600, loss=0.11512326449155807, Computation time: 0.0
# step=18700, loss=0.012099970132112503, Computation time: 0.0
# step=18800, loss=0.011877203360199928, Computation time: 0.016797780990600586
# step=18900, loss=0.013382313773036003, Computation time: 0.0
# step=19000, loss=0.11115185171365738, Computation time: 0.0
# step=19100, loss=0.011688720434904099, Computation time: 0.0
# step=19200, loss=0.016857901588082314, Computation time: 0.01665663719177246
# step=19300, loss=0.011532379314303398, Computation time: 0.0
# step=19400, loss=0.013829280622303486, Computation time: 0.001973867416381836
# step=19500, loss=0.01140930037945509, Computation time: 0.0
# step=19600, loss=0.02704974263906479, Computation time: 0.0
# step=19700, loss=0.011350252665579319, Computation time: 0.0
# step=19800, loss=0.014199859462678432, Computation time: 0.0019979476928710938
# step=19900, loss=0.011439830996096134, Computation time: 0.011353015899658203

# %% [markdown]
# `eqx.filter_value_and_grad` will calculate the gradient with respect to all floating-point arrays in the first argument (`model`). In this case the `model` parameters will be differentiated, whilst `model.hidden_size` is an integer and will get `None` as its gradient.
#
# Likewise, `eqx.filter_jit` will look at all the arguments passed to `make_step`, and automatically JIT-trace every array and JIT-static everything else. In this case the `model` parameters and the data `x` and `y` will be traced, whilst `model.hidden_size` is an integer and will be static'd instead.
