# %%
import math
import matplotlib.pyplot as plt
from dataclasses import dataclass
from datetime import datetime
import time

import diffrax
import equinox as eqx
import jax
import jax.lax as lax
import jax.numpy as jnp
import jax.nn as jnn
import jax.random as jr
import numpy as np
import optax  # https://github.com/deepmind/optax
from optax.contrib import reduce_on_plateau as plateau

# %%
# MLP
class Func(eqx.Module):
    mlp: eqx.nn.MLP

    def __init__(self, in_size, out_size, width_size, depth, *, key, **kwargs):
        super().__init__(**kwargs)
        self.mlp = eqx.nn.MLP(
            in_size=in_size,
            out_size=out_size,
            width_size=width_size,
            depth=depth,
            activation=jnn.tanh, 
            # activation=jnn.softplus, 결과가 더 안 좋음
            key=key,
        )

    def __call__(self, t):
        if jnp.shape(t) == ():
            t = jnp.broadcast_to(t, (1,))
        return self.mlp(t)

# %%
@dataclass
class SIRConfig:
    beta: float = 0.025
    alpha: float = 0.2
    S0: float = 100.0
    I0: float = 1.0
    t0: float = 0.0
    t1: float = 30.0

    def y0(self):
        return jnp.array([self.S0, self.I0])

    def args(self):
        return (self.beta, self.alpha)

# %%
def get_data(dataset_size, config, ts=None, *, key):
    # Initial condition: (S0, I0)
    # y0 = jr.uniform(key, (2,), minval=0, maxval=100)
    y0 = config.y0()
    ts = jnp.linspace(config.t0, config.t1, dataset_size) if ts is None else ts

    def f(t, y, args):
        beta, alpha = args
        S, I = y
        dSdt = -beta * S * I
        dIdt = beta * S * I - alpha * I
        return jnp.array([dSdt, dIdt])

    solver = diffrax.Tsit5()
    dt0 = 0.1
    saveat = diffrax.SaveAt(ts=ts)
    sol = diffrax.diffeqsolve(
        (diffrax.ODETerm(f)), solver, 0, ts[-1], dt0, y0, args=config.args(), saveat=saveat
    )
    ys = sol.ys
    return ts, ys

# %%
def dataloader(arrays, batch_size, *, key):
    dataset_size = arrays[0].shape[0]
    assert all(array.shape[0] == dataset_size for array in arrays)
    assert dataset_size >= batch_size
    indices = np.arange(dataset_size)
    while True:
        perm = jr.permutation(key, indices)
        (key,) = jr.split(key, 1)
        start = 0
        end = batch_size
        while end <= dataset_size:
            batch_perm = perm[start:end]
            yield tuple(array[batch_perm] for array in arrays)
            start = end
            end = start + batch_size

# %%
def relative_error(pred, true):
    assert(pred.shape == true.shape)
    
    if pred.ndim == 0:  # Scalar case
        return jnp.abs(pred - true) / jnp.abs(true)
    else:  # Vector (or higher-dimension) case
        return jnp.linalg.norm(pred - true, 2) / jnp.linalg.norm(true, 2)
    
def get_experiment_id():
    return datetime.now().strftime("%Y%m%d%H%M%S%f")

# %%
def main(
    dataset_size=10,
    collocation_size=500,
    batch_size=10, # batch_size == dataset_size
    lr=3e-3,
    steps=10000,
    width_size=64,
    depth=2,
    seed=5678,
    config=SIRConfig(),
    plot=True
):
    batch_size = dataset_size
    test_data_key, data_key, col_key, model_key, loader_key = jr.split(jr.PRNGKey(seed), 5)
    ts, ys = get_data(dataset_size, config=config, key=data_key)
    cs = jr.uniform(col_key, (collocation_size,), minval=config.t0 + 0.001, maxval=config.t1 - 0.001)

    model = Func(in_size=1, out_size=2, width_size=width_size, depth=depth, key=model_key)
    optim = optax.adam(lr)
    opt_state = optim.init(eqx.filter(model, eqx.is_array))

    @eqx.filter_jit
    def pde_residual(network, x):
        beta, alpha = config.args()
        pred = network(x)
        S, I = pred[0], pred[1]
        jac = jax.jacrev(network)(x)
        dSdt, dIdt = jac[0], jac[1]

        res_S = dSdt + beta * S * I
        res_I = dIdt - beta * S * I + alpha * I

        ret = jnp.square(res_S) + jnp.square(res_I)
        return ret
    
    @eqx.filter_value_and_grad
    def grad_loss(model, ti, yi):
        # residual_at_col = jax.vmap(pde_residual, in_axes=(None, 0))(model, cs)
        # col_loss = jnp.mean(residual_at_col)
        
        y_pred = jax.vmap(model)(ti)
        data_loss = jnp.mean((y_pred - yi)**2)
        
        # y0_pred = model(config.t0)
        # init_loss = jnp.mean((y0_pred - config.y0())**2)

        # total_loss = col_loss + data_loss + init_loss
        return data_loss
        # return total_loss

    @eqx.filter_jit
    def make_step(model, ti, yi, opt_state):
        loss, grads = grad_loss(model, ti, yi)
        updates, opt_state = optim.update(grads, opt_state, value=loss)
        model = eqx.apply_updates(model, updates)
        return loss, model, opt_state

    loss_list = []
    for step, (ti, yi) in zip(range(steps), dataloader((ts, ys), batch_size, key=loader_key)):
        start = time.time()
        loss, model, opt_state = make_step(model, ti, yi, opt_state)
        loss = loss.item()
        loss_list.append(loss)
        end = time.time()
        if step % 100 == 0:
            print(f"step={step}, loss={loss}, Computation time: {end - start}, lr scale: {optax.tree.get(opt_state, 'scale')}")

    if plot:
        exact_ts, exact_ys = get_data(1000, config=config, key=test_data_key)
        model_y = jax.vmap(model)(exact_ts)

        # relative error 계산
        rel_S = relative_error(exact_ys[:, 0], model_y[:, 0])
        rel_I = relative_error(exact_ys[:, 1], model_y[:, 1])

        # Figure setup
        figure = plt.figure(figsize=(15,5))
        plt.suptitle(f'Results - PINN')

        # Subplot for Susceptible (S)
        ax1 = figure.add_subplot(1,3,1)
        ax1.plot(exact_ts, exact_ys[:, 0], color='C0', label="Susceptible")
        ax1.plot(exact_ts, model_y[:, 0], linestyle='--', lw=2, color='C2', label='Trained NN')
        ax1.scatter(ts, ys[:, 0], color='red', marker='x', label='Sampled Susceptible', alpha=0.6)
        ax1.set_title(f'S(Relative error: {rel_S:.2e})')
        ax1.set_xlabel('t')
        ax1.legend()

        # Subplot for Infected (I)
        ax2 = figure.add_subplot(1,3,2)
        ax2.plot(exact_ts, exact_ys[:, 1], color='C1', label="Infected")
        ax2.plot(exact_ts, model_y[:, 1], linestyle='--', lw=2, color='C3', label='Trained NN')
        ax2.scatter(ts, ys[:, 1], color='red', marker='x', label='Sampled Infected', alpha=0.6)
        ax2.set_title(f'I(Relative error: {rel_I:.2e})')
        ax2.set_xlabel('t')
        ax2.legend()

        # Subplot for Training Loss
        ax3 = figure.add_subplot(1,3,3)
        ax3.plot(loss_list, label='loss_total')
        ax3.set_yscale('log')  # y축을 로그 스케일로 변경
        ax3.set_ylim(1e-6, 1e1)  # 적당한 범위로 설정 (필요하면 조정 가능)
        ax3.set_title('loss')
        ax3.set_xlabel('epoch')
        ax3.legend()

        plt.tight_layout()
        plt.savefig(f"result/pinn_{get_experiment_id()}.png")

    return ts, ys, model

# %%
ts, ys, model = main(dataset_size=30)
# Out:
# step=0, loss=678.27392578125, Computation time: 0.2544076442718506, lr scale: None
# step=100, loss=348.9598693847656, Computation time: 0.003632783889770508, lr scale: None
# step=200, loss=214.6526641845703, Computation time: 0.0, lr scale: None
# step=300, loss=145.2157440185547, Computation time: 0.0, lr scale: None
# step=400, loss=100.68965148925781, Computation time: 0.0010309219360351562, lr scale: None
# step=500, loss=69.59642028808594, Computation time: 0.0, lr scale: None
# step=600, loss=47.560302734375, Computation time: 0.0, lr scale: None
# step=700, loss=31.920320510864258, Computation time: 0.0020139217376708984, lr scale: None
# step=800, loss=21.108253479003906, Computation time: 0.0, lr scale: None
# step=900, loss=13.94113826751709, Computation time: 0.0, lr scale: None
# step=1000, loss=9.332579612731934, Computation time: 0.0, lr scale: None
# step=1100, loss=6.38796329498291, Computation time: 0.0, lr scale: None
# step=1200, loss=4.522231101989746, Computation time: 0.0, lr scale: None
# step=1300, loss=3.35679292678833, Computation time: 0.0, lr scale: None
# step=1400, loss=2.623032331466675, Computation time: 0.0, lr scale: None
# step=1500, loss=2.1659793853759766, Computation time: 0.0021941661834716797, lr scale: None
# step=1600, loss=1.8844971656799316, Computation time: 0.0, lr scale: None
# step=1700, loss=1.1215349435806274, Computation time: 0.0, lr scale: None
# step=1800, loss=0.750404417514801, Computation time: 0.0, lr scale: None
# step=1900, loss=0.4756133556365967, Computation time: 0.00946187973022461, lr scale: None
# step=2000, loss=0.30259251594543457, Computation time: 0.008120059967041016, lr scale: None
# step=2100, loss=0.1928848773241043, Computation time: 0.0, lr scale: None
# step=2200, loss=0.12524138391017914, Computation time: 0.0, lr scale: None
# step=2300, loss=0.08166135102510452, Computation time: 0.0, lr scale: None
# step=2400, loss=0.05332832783460617, Computation time: 0.0, lr scale: None
# step=2500, loss=0.0322214737534523, Computation time: 0.0, lr scale: None
# step=2600, loss=0.019851986318826675, Computation time: 0.0, lr scale: None
# step=2700, loss=0.012890378013253212, Computation time: 0.0, lr scale: None
# step=2800, loss=0.007393152918666601, Computation time: 0.009003400802612305, lr scale: None
# step=2900, loss=0.0044594742357730865, Computation time: 0.0, lr scale: None
# step=3000, loss=0.002852143719792366, Computation time: 0.0, lr scale: None
# step=6900, loss=3.0352079193107784e-05, Computation time: 0.0, lr scale: None
# step=7000, loss=2.6715229978435673e-05, Computation time: 0.004136085510253906, lr scale: None
# step=7100, loss=5.1504659495549276e-05, Computation time: 0.0, lr scale: None
# step=7200, loss=2.8628151994780637e-05, Computation time: 0.0, lr scale: None
# step=7300, loss=2.5235895009245723e-05, Computation time: 0.0, lr scale: None
# step=7400, loss=4.800361057277769e-05, Computation time: 0.002196788787841797, lr scale: None
# step=7500, loss=2.8463182388804853e-05, Computation time: 0.0, lr scale: None
# step=7600, loss=2.4737597414059564e-05, Computation time: 0.0, lr scale: None
# step=7700, loss=0.000180321469088085, Computation time: 0.0, lr scale: None
# step=7800, loss=2.6265031920047477e-05, Computation time: 0.0, lr scale: None
# step=7900, loss=4.641771738533862e-05, Computation time: 0.0, lr scale: None
# step=8000, loss=3.10996692860499e-05, Computation time: 0.0, lr scale: None
# step=8100, loss=2.520042471587658e-05, Computation time: 0.0, lr scale: None
# step=8200, loss=0.000570115284062922, Computation time: 0.0, lr scale: None
# step=8300, loss=2.954773481178563e-05, Computation time: 0.0, lr scale: None
# step=8400, loss=2.3581098503200337e-05, Computation time: 0.002839326858520508, lr scale: None
# step=8500, loss=3.381862188689411e-05, Computation time: 0.0, lr scale: None
# step=8600, loss=2.5380855731782503e-05, Computation time: 0.0037221908569335938, lr scale: None
# step=8700, loss=2.186781603086274e-05, Computation time: 0.0, lr scale: None
# step=8800, loss=3.442290108068846e-05, Computation time: 0.0, lr scale: None
# step=8900, loss=2.4802571715554222e-05, Computation time: 0.0, lr scale: None
# step=9000, loss=2.1653346266248263e-05, Computation time: 0.0, lr scale: None
# step=9100, loss=5.3466184908756986e-05, Computation time: 0.002659320831298828, lr scale: None
# step=9200, loss=2.346850851608906e-05, Computation time: 0.011954784393310547, lr scale: None
# step=9300, loss=0.012552320025861263, Computation time: 0.0, lr scale: None
# step=9400, loss=2.7837832021759823e-05, Computation time: 0.0010075569152832031, lr scale: None
# step=9500, loss=2.2500529667013325e-05, Computation time: 0.0, lr scale: None
# step=9600, loss=0.0026230323128402233, Computation time: 0.0, lr scale: None
# step=9700, loss=2.553785998316016e-05, Computation time: 0.0, lr scale: None
# step=9800, loss=2.1867952455068007e-05, Computation time: 0.0, lr scale: None
# step=9900, loss=0.0005645256605930626, Computation time: 0.0, lr scale: None

# %% [markdown]
# `eqx.filter_value_and_grad` will calculate the gradient with respect to all floating-point arrays in the first argument (`model`). In this case the `model` parameters will be differentiated, whilst `model.hidden_size` is an integer and will get `None` as its gradient.
#
# Likewise, `eqx.filter_jit` will look at all the arguments passed to `make_step`, and automatically JIT-trace every array and JIT-static everything else. In this case the `model` parameters and the data `x` and `y` will be traced, whilst `model.hidden_size` is an integer and will be static'd instead.
